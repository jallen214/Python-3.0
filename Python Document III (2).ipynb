# %% [markdown]
# #### Data Collections 2 (Dictionaries, Sets) and Importing Modules

# %% [markdown]
# ## Tasks Today:
#
# 1) Dictionary <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Declaring (key, value) <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Accessing Values <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; ------ Exercise #1 - Print the eye color of each person in a double nested dict <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Adding New Pairs <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Modifying Values <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Removing Key, Value Pairs <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) Looping a Dictionary <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Looping Only Keys <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Looping Only Values <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; ------ Exercise #2 - Create a Function that Prints All Key Value Pairs within a print .format()  <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) sorted() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Lists with Dictionaries <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; k) Dictionaries with Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; l) Dictionaries with Dictionaries <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; ------ Exercise #3 - Write a Function that asks someone's name and address, and then stores that into a dictionary, which prints all names and addresses after they're done putting information in...  <br>
# 2) Dictionaries vs. Lists (over time)<br>
# 3) Set <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Declaring <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) .add() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) .remove() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) .union() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) .intersection() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) .difference() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Frozen Set <br>
# 4) Modules <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Importing Entire Modules <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Importing Methods Only <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Using the 'as' Keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Creating a Module <br>
# 5) Exercises <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Build a Shopping Cart <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Create Your Own Module <br>

# %% [markdown]
# ## Dictionary <br>
# <p>A collection of data with 'key:value' pairs. Dictionaries are ordered as of Python 3.6</p>

# %% [markdown]
# ##### Declaring (key, value)

# %%
# Keys should be unique
# Can use numbers or strings as keys

dict_1 = {}

# OR

dict_2 = dict()

# With data

dict_3 = {
    "Dave" : "255 Main Street",
    "Sean": "522 1st Street",
    0: "This is a value for this key of 0",
}
print(dict_3)
# Out:
# {'Dave': '255 Main Street', 'Sean': '522 1st Street', 0: 'This is a value for this key of 0'}

# %% [markdown]
# ##### Accessing Values

# %%
# dict(key)
# ^ this returns the value

print(dict_3['Dave'])
print(dict_3[0])
# Out:
# 255 Main Street
# This is a value for this key of 0

# %% [markdown]
# ## In-Class Exercise #1 - Print a formatted statement from the dictionary below <br>
# <p>The output should be '2018 Chevrolet Silverado'</p>

# %%
# use the dict below
truck = {
    'year': 2018,
    'make': 'Chevrolet',
    'model': 'Silverado'
}

year = input("What is the year?")
make = input("What is the make?")
model = input("What is the model?")

result_string = "My favorite truck is a {} {} {}".format(year, make, model)
print(result_string)
# Out:
# What is the year?2018
# What is the make?Chevrolet
# What is the model?Silverado
# My favorite truck is a 2018 Chevrolet Silverado

# %% [markdown]
# ##### Adding New Pairs

# %%
# dict(key) = value
dict_3['bob'] = 'From Ohio'

dict_3
# Out:
# {'Dave': '255 Main Street',
#  'Sean': '522 1st Street',
#  0: 'This is a value for this key of 0',
#  'bob': 'From Ohio'}

# %% [markdown]
# ##### Modifying Values

# %%
# dict_3[key] = value
dict_3['bob'] = 'Nashville'

dict_3
# Out:
# {'Dave': '255 Main Street',
#  'Sean': '522 1st Street',
#  0: 'This is a value for this key of 0',
#  'bob': 'Nashville'}

# %% [markdown]
# ##### Removing Key, Value Pairs

# %%
# del dict['key']

del dict_3['bob']

dict_3
# Out:
# {'Dave': '255 Main Street',
#  'Sean': '522 1st Street',
#  0: 'This is a value for this key of 0'}

# %% [markdown]
# ##### Looping a Dictionary

# %%
# .items()


for key, value in dict_3.items():
    print(key,value)
# Out:
# Dave 255 Main Street
# Sean 522 1st Street
# 0 This is a value for this key of 0

# %% [markdown]
# ##### Looping Only Keys

# %%
# .keys()
for key in dict_3.keys():
    print(key)
# Out:
# Dave
# Sean
# 0

# %% [markdown]
# ##### Looping Only Values

# %%
# .value()
for value in dict_3.values():
    print(value)
# Out:
# 255 Main Street
# 522 1st Street
# This is a value for this key of 0

# %% [markdown]
# ## In-Class Exercise #2 - Create a Function that Prints All Key Value Pairs within a print .format() <br>
# <p><b>Output should be:</b><br>
# Max has blue eyes<br>
# Lilly has brown eyes<br>
# Barney has blue eyes<br>
# etc.
# </p>

# %%
# use the dict below
def print_key_value_pairs(data):
    for key, value in data.items():
        print("{} has {} eyes".format(key, value))
        

people = {
    'Max': 'blue',
    'Lilly': 'brown',
    'Barney': 'blue',
    'Larney': 'brown',
    'Ted': 'purple'
}

print_key_value_pairs(people)
# Out:
# Max has blue eyes
# Lilly has brown eyes
# Barney has blue eyes
# Larney has brown eyes
# Ted has purple eyes

# %% [markdown]
# ##### sorted()

# %%
# sorts variables in order
# sorted(dict.values()) or dict.keys() or dict.items()

print(sorted(people.items()))
print(sorted(people.keys()))
print(sorted(people.values()))

new_variable = sorted(people.values())
print(new_variable)
# Out:
# [('Barney', 'blue'), ('Larney', 'brown'), ('Lilly', 'brown'), ('Max', 'blue'), ('Ted', 'purple')]
# ['Barney', 'Larney', 'Lilly', 'Max', 'Ted']
# ['blue', 'blue', 'brown', 'brown', 'purple']
# ['blue', 'blue', 'brown', 'brown', 'purple']

# %% [markdown]
# ##### List with Dictionaries

# %%
names = ["Dave", "Randy", "Greg", {"random_guy": "Robert", "random_girl": "Barbara"}]

print(names[3]["random_girl"])

# Get all the keys from a nested dictionary in a list
for keys in names[3].keys():
    print(keys)
# Out:
# Barbara
# random_guy
# random_girl

# %% [markdown]
# ##### Dictionaries with Lists

# %%
# be careful when using numbers as keys in dictionaries, don't confuse them with indexes

random_data = {
    "List1" : [54, 7, 11],
    "2": ["Smith", "ipod", "water bottle"],
}

for key in random_data['2']:
        print(key)
# Out:
# Smith
# ipod
# water bottle

# %% [markdown]
# ##### Dictionaries with Dictionaries

# %%
# to get values, must traverse through keys
food_dict = {
    "ice_cream": {
        "CHO": 2.99,
        "VA": 3.99,
        "Oreo": 5.99,
        "PB": 6.99,
    }
}

print(food_dict["ice_cream"]["PB"])


for i in food_dict["ice_cream"].keys():
    print(i)
# Out:
# 6.99
# CHO
# VA
# Oreo
# PB

# %% [markdown]
# ## Dictionaries vs. Lists (over time) Example of RUNTIME
# ### When inputting values in a Dictionary vs List

# %%
import time


# generate fake dictionary
d = {}

for i in range(10000000):
    d[i] = 'value'
    

# generate fake list
big_list = [x for x in range(10000000)]

# %%
# tracking time for dictionary
start_time = time.time()

print(d[9999999])

end_time = time.time() - start_time

print('Elapsed time for dictionary: {}'.format(end_time))


# tracking time for list
start_time = time.time()

for i in range(len(big_list)):
    if i == 9999999:
        print(i)

end_time = time.time() - start_time

print('Elapsed time for list: {}'.format(end_time))
# Out:
# value
# Elapsed time for dictionary: 0.0
# 9999999
# Elapsed time for list: 1.331192970275879

# %% [markdown]
# ## Exercise #3 - Write a Function that asks someone's name and address, and then stores that into a dictionary, and continues to do so until they choose to 'quit'. Once they quit, the program should print all names and addresses. <br>
# <p>
# <b>Proper steps:</b><br>
# step 1: write a function that takes in information and stores it in a dictionary<br>
# step 2: define an empty dictionary to work with<br>
# step 3: create our loop, which asks the user for information until they quit<br>
# step 4: ask for the information, and store it into variables<br>
# step 5: check if the user types quit<br>
# step 5a: print out all information<br>
# step 5b: break out of the loop<br>
# step 6: if they didn't quit, add the information to the dictionary<br>
# step 7: invoke the function by calling it
# </p>

# %%
from IPython.display import clear_output

def get_information():
    information_dict = {}  # Step 2: Define an empty dictionary
    
    while True:  # Step 3: Create a loop until the user chooses to quit
        name = input("Enter the name (or 'quit' to exit): ")
        if name.lower() == 'quit':  # Step 5: Check if the user types quit
            # Step 5a: Print out all information
            clear_output(wait=True)
            print("All names and addresses:")
            for person, address in information_dict.items():
                print(f"{person}: {address}")
            break  # Step 5b: Break out of the loop if the user quits
        
        address = input("Enter the address: ")  # Step 4: Ask for information
        
        # Step 6: Add the information to the dictionary
        information_dict[name] = address
        clear_output(wait=True)

    return information_dict

# Step 7: Invoke the function by calling it
user_information = get_information()
# Out:
# All names and addresses:
# Mike: 4456 Shore Dr
# Dom: 6768 Westpoint St
# q: 2222 North St

# %% [markdown]
# ## Set <br>
# <p>A Set is an unordered collection data type that is iterable (loop), mutable, and has no duplicate elements.<br>Major advantage is that it is highly optimized in checking if something is in the set, as opposed to checking if something is in a list.</p>

# %% [markdown]
# ##### Declaring

# %%
# set() or {}
# no order {3, 2, 1} outputs as {1, 2, 3}
nums = {4,1,6,4}

print(nums)
# Out:
# {1, 4, 6}

# %% [markdown]
# ##### .add()

# %%
# set.add()
nums.add(56)
print(nums)
# Out:
# {56, 1, 4, 6}

# %% [markdown]
# ##### .remove()

# %%
# removes by value
# set.remove()
# nums.remove(56)

nums.remove(56)
print(nums)
# Out:
# {1, 4, 6}

# %% [markdown]
# ##### .union()

# %%
# Returns a union of two sets, can also use '|' or set.union(set)
# joins all numbers, gets rid of duplicates
s1 = {1,2,3,4}
s2 = {3,4,5,6}

s3 = s1.union(s2)

print(s3)

# OR

s4 = s1 | s2
print(s4)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ##### .intersection()

# %%
# Returns an intersection of two sets, can also use '&'
# only takes similar elements from both sets

s5 = s2 & s1

print(s5)

# OR

s6 = s1.intersection(s2)
print(s6)
# Out:
# {3, 4}
# {3, 4}

# %% [markdown]
# ##### .difference()

# %%
# Returns a set containing all the elements of invoking set that are not in the second set, can also use '-'
# only takes values from the first set that are not in the second set
# order matters
s7 = s2 - s1

# OR

s8 = s1.difference(s2)

print(s1)
print(s2)
print(s7)
print(s8)
# Out:
# {1, 2, 3, 4}
# {3, 4, 5, 6}
# {5, 6}
# {1, 2}

# %% [markdown]
# ##### .clear()

# %%
# Empties the whole set
# set.clear()
s8.clear()
print(s8)
# Out:
# set()

# %% [markdown]
# ##### Frozenset <br>
# <p>Frozen sets are immutable objects that only support methods and operators that produce a result without affecting the frozen set or sets to which they are applied.</p><br><b>Unique & Immutable</b>

# %%
# frozenset([])
s3.add(56)
my_frozen_set = frozenset(s3)
print(my_frozen_set)

my_frozen_set.add(56)
# Out:
# frozenset({1, 2, 3, 4, 5, 6, 56})
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12544\3223112350.py in <module>
#       4 print(my_frozen_set)
#       5
# ----> 6 my_frozen_set.add(56)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# ## Modules

# %% [markdown]
# ##### Importing Entire Modules

# %%
# import or from 'xxx' import *
# import math
from math import pi
from math import floor

print(pi)
print(floor(pi))
# Out:
# 3.141592653589793
# 3

# %% [markdown]
# ##### Importing Methods Only

# %%
# from 'xxx' import 'xxx'
# from math import floor

from math import floor, pi

print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ##### Using the 'as' Keyword

# %%
# from 'xxx' import 'xxx' as 'xxx' or import 'xxx' as 'xxx'
# from math import floor as f
from math import floor as f, pi as p

print(f(p))
# Out:
# 3

# %% [markdown]
# ##### Creating a Module

# %%
import module

print(module.printName('Brandon'))
# Out:
# Hello Mr/Ms {name}...we've been waiting for you!

# %% [markdown]
# # Exercises

# %% [markdown]
# ### 1) Build a Shopping Cart <br>
# <p><b>You can use either lists or dictionaries. The program should have the following capabilities:</b><br><br>
# 1) Takes in input <br>
# 2) Stores user input into a dictionary or list <br>
# 3) The User can add or delete items <br>
# 4) The User can see current shopping list <br>
# 5) The program Loops until user 'quits' <br>
# 6) Upon quiting the program, print out all items in the user's list <br>
# </p>

# %%
from IPython.display import clear_output

# Ask the user four bits of input: Do you want to : Show/Add/Delete or Quit?

foods = []
prices = []
total = 0

while True:
    food = input("Enter a food to buy(q to quit): ")
    if food == "q":
        break
    else:
        price = float(input(f"Enter the price of a {food}: $"))
        foods.append(food)
        prices.append(price)
 
print("----- YOUR CART -----")

for food in foods:
    print(food)
    
for price in prices:
    total += price
    
print(f"Your total is: ${total}")
# Out:
# Enter a food to buy(q to quit): Pizza
# Enter the price of a Pizza: $3.50
# Enter a food to buy(q to quit): Hotdog
# Enter the price of a Hotdog: $4.00
# Enter a food to buy(q to quit): Burger
# Enter the price of a Burger: $3.00
# Enter a food to buy(q to quit): q
# ----- YOUR CART -----
# Pizza
# Hotdog
# Burger
# Your total is: $10.5

# %% [markdown]
# ### 2) Create a Module in VS Code and Import It into jupyter notebook <br>
# <p><b>Module should have the following capabilities:</b><br><br>
# 1) Has a function to calculate the square footage of a house <br>
#     <b>Reminder of Formula: Length X Width == Area<br>
#         <hr>
# 2) Has a function to calculate the circumference of a circle <br><br>
# <b>Program in Jupyter Notebook should take in user input and use imported functions to calculate a circle's circumference or a houses square footage</b>
# </p>

# %%
import pie
print(pie.area(2,2))

print(pie.calculate_circumference(10))
# Out:
# 4
# 62.800000000000004
